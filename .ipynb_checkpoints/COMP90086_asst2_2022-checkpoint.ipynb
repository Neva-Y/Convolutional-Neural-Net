# %% [markdown]
# ## The University of Melbourne, School of Computing and Information Systems
# # COMP90086 Computer Vision, 2022 Semester 2
#
# ## Assignment 2

# %% [markdown]
# **Student Name:**    `PLEASE ENTER YOUR NAME HERE`
#
# **Student ID:**     `PLEASE ENTER YOUR ID HERE`

# %% [markdown]
# ## This iPython notebook is a template which you should use for your Assignment 2 submission. This file should be submitted at the **Assignment 2: Code** link on the LMS.
#
# In addition to this file, you should submit a written report explaining your results at the **Assignment 2: Report** link on the LMS. Please see the assignment specification for details on what must be included in the report for each question.
#
# *Adding proper comments to your code is MANDATORY.*

# %% [markdown]
# ### 1. CNN implementation
#
# In this problem, you will implement a CNN to classify the yoga32 dataset. The following code section will load the dataset from a folder that you specify. You may change the batch sizes and validation percentage if you wish, but otherwise it is recommended that you do not modify this section.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import math
import secrets

data_dir = "./yoga32"
train_batch_size = 32
rand_seed = secrets.randbelow(1_000_000_000) # random seed for train/val split
# note that same seed must be used for both to ensure no overlap in train/val data

# Get training images from 'train' directory
train_data = tf.keras.utils.image_dataset_from_directory(
    data_dir+'/train',
    validation_split=0.2,
    subset="training",
    seed=rand_seed,
    image_size=(32, 32),
    batch_size=train_batch_size)

# Get validation images from 'train' directory
val_data = tf.keras.utils.image_dataset_from_directory(
    data_dir+'/train',
    validation_split=0.2,
    subset="validation",
    seed=rand_seed,
    image_size=(32, 32),
    batch_size=train_batch_size)

# Output list of class names
class_names = train_data.class_names
print(class_names)

# Normalise the testing and training data 
def normalise_image(image, label):
    return tf.cast(image, tf.float32) / 255.0, label 

train_data = train_data.map(normalise_image)
val_data = val_data.map(normalise_image)
# Note: To train a model with the dataset loaded above, pass the train and val
# datasets to the fit() function, like so:
# myCNNmodel.fit(train_data, validation_data=val_data, epochs=number_of_epochs)
# Out:
# Found 520 files belonging to 10 classes.
# Using 416 files for training.
# Found 520 files belonging to 10 classes.
# Using 104 files for validation.
# ['bridge', 'childs', 'downwarddog', 'mountain', 'plank', 'seatedforwardbend', 'tree', 'trianglepose', 'warrior1', 'warrior2']

# %% [markdown]
# 1.1. Implement the CNN shown in the assignment specification and train it on the provided dataset. Plot the training accuracy and validation accuracy over epochs.

# %%
cnn = keras.Sequential(
    [
        layers.InputLayer((32, 32, 3)),
        
        layers.Conv2D(16, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        layers.Conv2D(16, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'), # fill in
        layers.Conv2D(24, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        layers.Conv2D(24, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'), # fill in
        layers.Flatten(),
        layers.Dense(10, activation='softmax')
    ], 
)

cnn.compile(optimizer='adam',
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
            metrics=['accuracy'])

history_cnn = cnn.fit(train_data, validation_data=val_data, epochs=20);

plt.plot(history_cnn.history['accuracy'], label='Train')
plt.plot(history_cnn.history['val_accuracy'], label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Training and validating accuracy')
plt.legend()
plt.show()

plt.plot(history_cnn.history['loss'], label='Train')
plt.plot(history_cnn.history['val_loss'], label='Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title('Training and validating loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 28ms/step - loss: 2.3054 - accuracy: 0.1202 - val_loss: 2.3077 - val_accuracy: 0.0577
# Epoch 2/20
# 13/13 [==============================] - 0s 20ms/step - loss: 2.2917 - accuracy: 0.1178 - val_loss: 2.3162 - val_accuracy: 0.0481
# Epoch 3/20
# 13/13 [==============================] - 0s 20ms/step - loss: 2.2635 - accuracy: 0.1731 - val_loss: 2.2985 - val_accuracy: 0.0385
# Epoch 4/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.1794 - accuracy: 0.2260 - val_loss: 2.1616 - val_accuracy: 0.1923
# Epoch 5/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.9659 - accuracy: 0.3582 - val_loss: 1.8977 - val_accuracy: 0.3365
# Epoch 6/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.7364 - accuracy: 0.4375 - val_loss: 1.8196 - val_accuracy: 0.4038
# Epoch 7/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.5722 - accuracy: 0.4663 - val_loss: 1.7094 - val_accuracy: 0.3942
# Epoch 8/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.4286 - accuracy: 0.5457 - val_loss: 1.6274 - val_accuracy: 0.4615
# Epoch 9/20
# 13/13 [==============================] - 0s 22ms/step - loss: 1.2552 - accuracy: 0.6010 - val_loss: 1.5890 - val_accuracy: 0.4423
# Epoch 10/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.1410 - accuracy: 0.6322 - val_loss: 1.6091 - val_accuracy: 0.4712
# Epoch 11/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.0529 - accuracy: 0.6442 - val_loss: 1.5680 - val_accuracy: 0.4423
# Epoch 12/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.9626 - accuracy: 0.6899 - val_loss: 1.5838 - val_accuracy: 0.5000
# Epoch 13/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.8639 - accuracy: 0.7380 - val_loss: 1.5230 - val_accuracy: 0.4808
# Epoch 14/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.7481 - accuracy: 0.7716 - val_loss: 1.5503 - val_accuracy: 0.4615
# Epoch 15/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.6964 - accuracy: 0.7620 - val_loss: 1.6242 - val_accuracy: 0.4615
# Epoch 16/20
# 13/13 [==============================] - 0s 20ms/step - loss: 0.6064 - accuracy: 0.8173 - val_loss: 1.6525 - val_accuracy: 0.5096
# Epoch 17/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.5671 - accuracy: 0.8197 - val_loss: 1.7088 - val_accuracy: 0.4808
# Epoch 18/20
# 13/13 [==============================] - 0s 20ms/step - loss: 0.4910 - accuracy: 0.8438 - val_loss: 1.8275 - val_accuracy: 0.5000
# Epoch 19/20
# 13/13 [==============================] - 0s 20ms/step - loss: 0.4157 - accuracy: 0.8750 - val_loss: 1.7119 - val_accuracy: 0.5288
# Epoch 20/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.3471 - accuracy: 0.8798 - val_loss: 2.0745 - val_accuracy: 0.5192

# %%
cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 30, 30, 16)        448
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 16)        2320
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 12, 12, 24)        3480
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 10, 10, 24)        5208
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 5, 5, 24)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 600)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                6010
# =================================================================
# Total params: 17,466
# Trainable params: 17,466
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 1.2. Modify the CNN (see assignment spec for details) and train it on the provided dataset.  Plot the training accuracy and validation accuracy over epochs.

# %%
cnn = keras.Sequential(
    [
        layers.InputLayer((32, 32, 3)),
        
        layers.Conv2D(16, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        
        layers.Conv2D(16, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'), # fill in
        
        layers.Conv2D(24, (3, 3), strides=(1, 1), activation='relu', 
                      padding='valid'), # fill in
        
        layers.Conv2D(24, (3, 3), strides=(1, 1), activation='relu', 
                      padding='valid', kernel_regularizer=regularizers.l2(0.01)), # fill in
        
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'), # fill in
        
        layers.Flatten(),
        
        layers.Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(0.05))
    ], 
)

cnn.compile(optimizer='adam',
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
            metrics=['accuracy'])

history_cnn = cnn.fit(train_data, validation_data=val_data, epochs=20)

plt.plot(history_cnn.history['accuracy'], label='Train')
plt.plot(history_cnn.history['val_accuracy'], label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Training and validating accuracy')
plt.legend()
plt.show()

plt.plot(history_cnn.history['loss'], label='Train')
plt.plot(history_cnn.history['val_loss'], label='Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title('Training and validating loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 31ms/step - loss: 3.3411 - accuracy: 0.0986 - val_loss: 3.1555 - val_accuracy: 0.0769
# Epoch 2/20
# 13/13 [==============================] - 0s 21ms/step - loss: 3.0100 - accuracy: 0.1466 - val_loss: 2.8908 - val_accuracy: 0.0288
# Epoch 3/20
# 13/13 [==============================] - 0s 20ms/step - loss: 2.7708 - accuracy: 0.1418 - val_loss: 2.7151 - val_accuracy: 0.0192
# Epoch 4/20
# 13/13 [==============================] - 0s 20ms/step - loss: 2.6055 - accuracy: 0.1274 - val_loss: 2.5820 - val_accuracy: 0.0481
# Epoch 5/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.4788 - accuracy: 0.1947 - val_loss: 2.4624 - val_accuracy: 0.1058
# Epoch 6/20
# 13/13 [==============================] - 0s 20ms/step - loss: 2.3064 - accuracy: 0.2524 - val_loss: 2.3278 - val_accuracy: 0.1635
# Epoch 7/20
# 13/13 [==============================] - 0s 20ms/step - loss: 2.0280 - accuracy: 0.3341 - val_loss: 2.0146 - val_accuracy: 0.3654
# Epoch 8/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.7399 - accuracy: 0.4880 - val_loss: 1.8455 - val_accuracy: 0.4038
# Epoch 9/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.6406 - accuracy: 0.5072 - val_loss: 1.8380 - val_accuracy: 0.3942
# Epoch 10/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.5568 - accuracy: 0.5505 - val_loss: 1.6990 - val_accuracy: 0.4423
# Epoch 11/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.4409 - accuracy: 0.5889 - val_loss: 1.6307 - val_accuracy: 0.5192
# Epoch 12/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.3367 - accuracy: 0.6322 - val_loss: 1.6016 - val_accuracy: 0.4904
# Epoch 13/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.2497 - accuracy: 0.6707 - val_loss: 1.6162 - val_accuracy: 0.5192
# Epoch 14/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.1496 - accuracy: 0.7188 - val_loss: 1.5791 - val_accuracy: 0.5192
# Epoch 15/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.0823 - accuracy: 0.7139 - val_loss: 1.5711 - val_accuracy: 0.5481
# Epoch 16/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.9834 - accuracy: 0.7524 - val_loss: 1.7551 - val_accuracy: 0.4519
# Epoch 17/20
# 13/13 [==============================] - 0s 20ms/step - loss: 0.9247 - accuracy: 0.7861 - val_loss: 1.6453 - val_accuracy: 0.5385
# Epoch 18/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.9293 - accuracy: 0.7644 - val_loss: 1.6505 - val_accuracy: 0.5288
# Epoch 19/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.8702 - accuracy: 0.7909 - val_loss: 1.6545 - val_accuracy: 0.5577
# Epoch 20/20
# 13/13 [==============================] - 0s 21ms/step - loss: 0.8541 - accuracy: 0.8029 - val_loss: 1.7503 - val_accuracy: 0.5192

# %%
def augment(image, label):
    new_height = new_width = 32
    image = tf.image.resize(image, (new_height,new_width))
    # Changing ~10% of testing set into grayscale, tiling into 3 dim to fit CNN
    if tf.random.uniform((), minval=0, maxval=1) < 0.1:
        image = tf.tile(tf.image.rgb_to_grayscale(image), [1, 1, 3])
    # Randomly change the brightness of the images
    image = tf.image.random_brightness(image, max_delta=0.2)
    # Randomly change the constrast of the images
    image = tf.image.random_constrast(image, lower=0.1, upper=0.2)
    # Randomly horizontally flip the images
    image = tf.image.random_flip_right(image)
    return image, label


data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.Resizing(height=32, width=32),
        layers.experimental.preprocessing.RandomFlip(mode="horizontal"),
        layers.experimental.preprocessing.RandomContrast(factor=0.15),
    ]
)

# %%
cnn = keras.Sequential(
    [
        layers.InputLayer((32, 32, 3)),
        
        data_augmentation,
        
        layers.Conv2D(16, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        
        layers.Conv2D(16, (3, 3), strides=(1, 1), activation='relu', padding='valid'), # fill in
        
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'), # fill in
        
        layers.Conv2D(24, (3, 3), strides=(1, 1), activation='relu', 
                      padding='valid'), # fill in
        
        layers.Conv2D(24, (3, 3), strides=(1, 1), activation='relu', 
                      padding='valid', kernel_regularizer=regularizers.l2(0.01)), # fill in
        
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'), # fill in
        
        layers.Flatten(),
        
        layers.Dense(10, activation='softmax', kernel_regularizer=regularizers.l2(0.05))
    ], 
)

cnn.compile(optimizer='adam',
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
            metrics=['accuracy'])

history_cnn = cnn.fit(train_data, validation_data=val_data, epochs=20)

plt.plot(history_cnn.history['accuracy'], label='Train')
plt.plot(history_cnn.history['val_accuracy'], label='Validation')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.title('Training and validating accuracy')
plt.legend()
plt.show()

plt.plot(history_cnn.history['loss'], label='Train')
plt.plot(history_cnn.history['val_loss'], label='Validation')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.title('Training and validating loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 1s 30ms/step - loss: 3.3587 - accuracy: 0.1034 - val_loss: 3.1904 - val_accuracy: 0.0192
# Epoch 2/20
# 13/13 [==============================] - 0s 21ms/step - loss: 3.0379 - accuracy: 0.1250 - val_loss: 2.9128 - val_accuracy: 0.0288
# Epoch 3/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.7973 - accuracy: 0.1274 - val_loss: 2.7295 - val_accuracy: 0.0192
# Epoch 4/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.6253 - accuracy: 0.1202 - val_loss: 2.6056 - val_accuracy: 0.0192
# Epoch 5/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.4830 - accuracy: 0.2236 - val_loss: 2.4595 - val_accuracy: 0.1250
# Epoch 6/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.3072 - accuracy: 0.3053 - val_loss: 2.2942 - val_accuracy: 0.2115
# Epoch 7/20
# 13/13 [==============================] - 0s 21ms/step - loss: 2.1472 - accuracy: 0.3293 - val_loss: 2.1655 - val_accuracy: 0.2692
# Epoch 8/20
# 13/13 [==============================] - 0s 22ms/step - loss: 1.9564 - accuracy: 0.3990 - val_loss: 1.9716 - val_accuracy: 0.3846
# Epoch 9/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.8691 - accuracy: 0.4231 - val_loss: 1.8987 - val_accuracy: 0.3942
# Epoch 10/20
# 13/13 [==============================] - 0s 20ms/step - loss: 1.7338 - accuracy: 0.4688 - val_loss: 1.8429 - val_accuracy: 0.4231
# Epoch 11/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.6353 - accuracy: 0.5120 - val_loss: 1.6694 - val_accuracy: 0.5000
# Epoch 12/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.5085 - accuracy: 0.5673 - val_loss: 1.7711 - val_accuracy: 0.4519
# Epoch 13/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.4377 - accuracy: 0.6202 - val_loss: 1.7709 - val_accuracy: 0.4615
# Epoch 14/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.4437 - accuracy: 0.6010 - val_loss: 1.7526 - val_accuracy: 0.4519
# Epoch 15/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.3641 - accuracy: 0.6154 - val_loss: 1.5505 - val_accuracy: 0.5192
# Epoch 16/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.2940 - accuracy: 0.6274 - val_loss: 1.6504 - val_accuracy: 0.5288
# Epoch 17/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.2346 - accuracy: 0.6611 - val_loss: 1.4529 - val_accuracy: 0.5673
# Epoch 18/20
# 13/13 [==============================] - 0s 22ms/step - loss: 1.2317 - accuracy: 0.6683 - val_loss: 1.5053 - val_accuracy: 0.5192
# Epoch 19/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.1695 - accuracy: 0.6635 - val_loss: 1.7164 - val_accuracy: 0.5000
# Epoch 20/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.1789 - accuracy: 0.6683 - val_loss: 1.5587 - val_accuracy: 0.5673

# %% [markdown]
# ### 2. Error anaylsis
# Evaluate your CNN model from question 1.2 on the test dataset. See assignment spec for details.

# %%
class Metrics(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self._data = []

    def on_epoch_end(self, batch, logs={}):
        x_test, y_test = self.validation_data[0], self.validation_data[1]
        y_predict = np.asarray(model.predict(x_test))

        true = np.argmax(y_test, axis=1)
        pred = np.argmax(y_predict, axis=1)
        
        cm = confusion_matrix(true, pred)
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        self._data.append({
            'classLevelaccuracy':cm.diagonal() ,
        })
        return

    def get_data(self):
        return self._data
    
metrics = Metrics()
history = cnn.fit(train_data, validation_data=val_data, epochs=20, callbacks=[metrics])
metrics.get_data()
# Out:
# Epoch 1/20
# 13/13 [==============================] - 0s 21ms/step - loss: 1.1532 - accuracy: 0.6851 - val_loss: 1.5403 - val_accuracy: 0.5865
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [141], in <cell line: 23>()
#      20         return self._data
#      22 metrics = Metrics()
# ---> 23 history = cnn.fit(train_data, validation_data=val_data, epochs=20, callbacks=[metrics])
#      24 metrics.get_data()
#
# File ~\anaconda3\envs\tf-gpu\lib\site-packages\keras\engine\training.py:1230, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1227   val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1228   epoch_logs.update(val_logs)
# -> 1230 callbacks.on_epoch_end(epoch, epoch_logs)
#    1231 training_logs = epoch_logs
#    1232 if self.stop_training:
#
# File ~\anaconda3\envs\tf-gpu\lib\site-packages\keras\callbacks.py:413, in CallbackList.on_epoch_end(self, epoch, logs)
#     411 logs = self._process_logs(logs)
#     412 for callback in self.callbacks:
# --> 413   callback.on_epoch_end(epoch, logs)
#
# Input In [141], in Metrics.on_epoch_end(self, batch, logs)
#       5 def on_epoch_end(self, batch, logs={}):
# ----> 6     x_test, y_test = self.validation_data[0], self.validation_data[1]
#       7     y_predict = np.asarray(model.predict(x_test))
#       9     true = np.argmax(y_test, axis=1)
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ### 3. Visualisation
# Visualise the feature space that your model uses to classify images. See assignment spec for details.
